# %% [markdown]
# <h2 style="
#     background: linear-gradient(135deg, #4A90E2, #007AFF);
#     padding: 12px;
#     border-radius: 10px;
#     color: white;
#     text-align: center;
#     font-size: 24px;
#     box-shadow: 0 2px 6px rgba(0,0,0,0.15);
# ">
# PARTIE 3 : Étude Expérimentale
# </h2>
#
# <div style="
#     background-color:#F9FAFB;
#     border-left: 5px solid #4A90E2;
#     padding: 16px 20px;
#     border-radius: 8px;
#     margin-top: 12px;
#     font-size: 15px;
#     line-height: 1.6;
#     text-align: justify;
# ">
# Cette section présente une <strong>analyse expérimentale détaillée</strong> de l’algorithme Tabou appliqué à un ensemble de tests répétés sur une même instance du problème.
# L’objectif est de quantifier la stabilité, la robustesse et l’efficacité de la méthode à travers des mesures statistiques, tout en identifiant les marges d’amélioration possibles.
# </div>
#
# <h3 style="color:#333; font-size:18px; margin-top:16px;">1. Méthodologie expérimentale</h3>
# <div style="
#     background-color:#F9FAFB;
#     border-left: 5px solid #4A90E2;
#     padding: 14px 20px;
#     border-radius: 8px;
#     margin-top: 10px;
#     font-size: 15px;
#     line-height: 1.6;
#     text-align: justify;
# ">
# L’expérience consiste à exécuter **20 lancements indépendants** de l’algorithme Tabou sur une même matrice de distances.
#
# Chaque exécution fournit :
# <ul>
#   <li>Le coût total de la meilleure solution trouvée</li>
#   <li>Le temps d’exécution correspondant</li>
# </ul>
# Les résultats sont ensuite stockés dans un **DataFrame Pandas**, permettant une analyse statistique complète (moyenne, écart-type, IC95%, Z-scores, etc.).
# </div>
#
# <h3 style="color:#333; font-size:18px; margin-top:16px;">2. Analyse statistique globale</h3>
# <div style="
#     background-color:#F9FAFB;
#     border-left: 5px solid #4A90E2;
#     padding: 14px 20px;
#     border-radius: 8px;
#     margin-top: 10px;
#     font-size: 15px;
#     line-height: 1.6;
#     text-align: justify;
# ">
# Les indicateurs suivants sont calculés :
# <ul>
#   <li><strong>Moyenne</strong> du coût total (<code>mean_time</code>)</li>
#   <li><strong>Médiane</strong> (<code>median_time</code>)</li>
#   <li><strong>Écart-type</strong> (<code>std_time</code>) — mesure de dispersion</li>
#   <li><strong>Minimum et maximum</strong> des coûts</li>
#   <li><strong>Gap</strong> = 100 × ((moyenne - minimum)/minimum)</li>
#   <li><strong>Intervalle de confiance à 95 %</strong> (IC95%) pour la moyenne</li>
# </ul>
# Ces valeurs permettent d’évaluer la **variabilité des résultats** et la **convergence** de l’algorithme.
# </div>
#
# <h3 style="color:#333; font-size:18px; margin-top:16px;">3. Visualisation et interprétation des résultats</h3>
# <div style="
#     background-color:#F9FAFB;
#     border-left: 5px solid #4A90E2;
#     padding: 14px 20px;
#     border-radius: 8px;
#     margin-top: 10px;
#     font-size: 15px;
#     line-height: 1.6;
#     text-align: justify;
# ">
# Plusieurs graphiques sont générés avec Matplotlib :
#
# <b>a) Boxplot enrichi — distribution des coûts totaux</b>
# <ul>
#   <li>Montre la dispersion des coûts sur les 20 lancements</li>
#   <li>Annotations : moyenne, médiane, min, max, IC95%</li>
#   <li>Valeurs extrêmes indiquent les runs les plus performants ou faibles</li>
# </ul>
#
# <b>b) Courbe du coût total par run</b>
# <ul>
#   <li>Visualise la stabilité de l’algorithme au fil des exécutions</li>
#   <li>Ligne horizontale = moyenne, zone grisée = IC95%</li>
# </ul>
#
# <b>c) Barres du gap (%)</b>
# <ul>
#   <li>Exprime l’écart relatif de chaque run par rapport au meilleur résultat</li>
#   <li>Ligne rouge (7%) = seuil de tolérance pour identifier les runs moins performants</li>
# </ul>
#
# <b>d) Z-score plot — détection d’anomalies</b>
# <ul>
#   <li>Runs avec |Z| > 2 → potentiels outliers (piège local ou mauvais paramétrage)</li>
#   <li>Permet de savoir le nombre de runs anormales</li>
# </ul>
# </div>
#
# <h3 style="color:#333; font-size:18px; margin-top:16px;">4. Interprétation et discussion</h3>
# <div style="
#     background-color:#F9FAFB;
#     border-left: 5px solid #4A90E2;
#     padding: 14px 20px;
#     border-radius: 8px;
#     margin-top: 10px;
#     font-size: 15px;
#     line-height: 1.6;
#     text-align: justify;
# ">
# Les graphiques et indicateurs montrent généralement une bonne cohérence des résultats :
# <ul>
#   <li>L’écart-type reste modéré → stabilité algorithmique</li>
#   <li>Quelques runs peuvent avoir un Z-score > 2 → sensibilité aux conditions initiales ou paramètres comme le nombre de camions</li>
#   <li>Gap moyen < 10% → bonne performance moyenne</li>
# </ul>
# L’IC95% offre une estimation fiable du coût moyen attendu, consolidant la validité statistique des observations.
# <h3 style="color:#2E86C1; margin-top:25px;">Exemples de graphes obtenus</h3>
# <p style="margin-bottom:15px;">
# Les graphiques suivants illustrent les résultats de l’étude expérimentale sur 20 exécutions de l’algorithme Tabou.
# Ils permettent de visualiser la dispersion des coûts, les écarts (gap %), la stabilité des runs et la détection d’anomalies via le Z-score.
# </p>
#
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(350px, 1fr)); gap: 20px; margin-top:20px;">
#
#   <div style="margin-bottom: 15px;background:#f9f9f9; border-radius:15px; box-shadow:0 3px 8px rgba(0,0,0,0.1); padding:10px; text-align:center;">
#     <h4 style="color:#4A90E2; margin-bottom:10px;">Boxplot — Distribution des coûts</h4>
#     <img src="images/graph1.webp" alt="Boxplot des coûts totaux" style="width:100%; border-radius:10px;">
#   </div>
#
#   <div style="margin-bottom: 15px;background:#f9f9f9; border-radius:15px; box-shadow:0 3px 8px rgba(0,0,0,0.1); padding:10px; text-align:center;">
#     <h4 style="color:#4A90E2; margin-bottom:10px;">Évolution du coût total par run</h4>
#     <img src="images/graph2.webp" alt="Évolution du coût total" style="width:100%; border-radius:10px;">
#   </div>
#
#   <div style="margin-bottom: 15px;background:#f9f9f9; border-radius:15px; box-shadow:0 3px 8px rgba(0,0,0,0.1); padding:10px; text-align:center;">
#     <h4 style="color:#4A90E2; margin-bottom:10px;">Gap (%) — Écart relatif au meilleur résultat</h4>
#     <img src="images/graph3.webp" alt="Graphique du gap en pourcentage" style="width:100%; border-radius:10px;">
#   </div>
#
#   <div style="margin-bottom: 15px;background:#f9f9f9; border-radius:15px; box-shadow:0 3px 8px rgba(0,0,0,0.1); padding:10px; text-align:center;">
#     <h4 style="color:#4A90E2; margin-bottom:10px;">Z-score — Détection des anomalies</h4>
#     <img src="images/graph4.webp" alt="Graphique du Z-score" style="width:100%; border-radius:10px;">
#   </div>
#
# </div>
#
# </div>
#
# <h3 style="color:#333; font-size:18px; margin-top:16px;">5. Limites et perspectives d’amélioration</h3>
# <div style="
#     background-color:#F9FAFB;
#     border-left: 5px solid #4A90E2;
#     padding: 14px 20px;
#     border-radius: 8px;
#     margin-top: 10px;
#     font-size: 15px;
#     line-height: 1.6;
#     text-align: justify;
# ">
# Les variations observées d’un run à l’autre montrent :
# <ul>
#   <li>Dépendance aux conditions initiales</li>
#   <li>Possible stagnation prématurée (optimum local)</li>
#   <li>Dispersion du temps de calcul liée à la nature heuristique</li>
# </ul>
# <b>Pistes d’amélioration :</b>
# <ul>
#   <li>Diversification adaptative pour éviter stagnation</li>
#   <li>Adapter dynamiquement la taille de la liste Tabou selon la phase</li>
#   <li>Combiner Tabou avec multi-start intelligent ou hybridation avec recuit simulé</li>
# </ul>
# </div>
#
# <h3 style="color:#333; font-size:18px; margin-top:16px;">6. Conclusion</h3>
# <div style="
#     background-color:#F9FAFB;
#     border-left: 5px solid #4A90E2;
#     padding: 14px 20px;
#     border-radius: 8px;
#     margin-top: 10px;
#     font-size: 15px;
#     line-height: 1.6;
#     text-align: justify;
# ">
# Cette étude expérimentale montre que l’algorithme Tabou produit des résultats fiables et compétitifs, avec une variabilité maîtrisée.
# L’analyse statistique permet de quantifier la robustesse de la méthode et d’identifier des leviers précis d’optimisation.
# Ces travaux constituent une base solide pour des améliorations futures visant à renforcer la stabilité et la qualité des solutions.
# </div>

# %%
import csv
import numpy as np
from collections import deque
import copy
import random
import time
import math
import os
import pandas as pd
import matplotlib.pyplot as plt

# ================== CONFIG / SWITCH ==================
print("=== Sélection de l'instance ===")
print("1 - 6X6.csv")
print("2 - 11X11.csv")
print("3 - 51X51.csv")
print("4 - 101X101.csv")
print("5 - 201X201.csv")
print("6 - 501X501.csv")
print("7 - 1001X1001.csv")
print("8 - 1501X1501.csv")
print("9 - 2001X2001.csv")
choix = input("Choisissez la matrice à utiliser (1-9) : ")

if choix == "1":
    csv_path = "instance/6X6.csv"
    nameFile = "6X6.csv"
elif choix == "2":
    csv_path = "instance/11X11.csv"
    nameFile = "11X11.csv"
elif choix == "3":
    csv_path = "instance/51X51.csv"
    nameFile = "51X51.csv"
elif choix == "4":
    csv_path = "instance/101X101.csv"
    nameFile = "101X101.csv"
elif choix == "5":
    csv_path = "instance/201X201.csv"
    nameFile = "201X201.csv"
elif choix == "6":
    csv_path = "instance/501X501.csv"
    nameFile = "501X501.csv"
elif choix == "7":
    csv_path = "instance/1001X1001.csv"
    nameFile = "1001X1001.csv"
elif choix == "8":
    csv_path = "instance/1501X1501.csv"
    nameFile = "1501X1501.csv"
elif choix == "9":
    csv_path = "instance/2001X2001.csv"
    nameFile = "2001X2001.csv"
else:
    csv_path = "instance/6X6.csv"
    nameFile = "6X6.csv"

try:
    nbTrucks = int(input("Nombre de camions à utiliser : "))
except:
    nbTrucks = 10


depot = 0
MAX_CYCLE_TIME = 720  
SEUIL1 = 240
SEUIL2 = 480

# === Utilitaires de lecture (définit avant usage) ===
def lire_matrice_csv(filename):
    matrice = []
    with open(filename, newline='') as f:
        lecteur = csv.reader(f)
        for ligne in lecteur:
            # ignorer champs vides
            valeurs = [int(float(x)) for x in ligne if x.strip() != ""]
            if valeurs:
                matrice.append(valeurs)
    return matrice


if not os.path.exists("matrice"):
    os.makedirs("matrice")

# === Chargement de la matrice de base (celle choisie) ===
try:

    try:
        base_matrix = np.loadtxt(csv_path, delimiter=",", dtype=int).tolist()
    except Exception:
        base_matrix = lire_matrice_csv(csv_path)
except FileNotFoundError:
    raise FileNotFoundError(f"Fichier introuvable : {csv_path}")

matrix = base_matrix

# ================== Fonctions algorithme (inchangées en interface) ==================
def voisinMinPoid(matrix_local, listeClient, cur):
    poidMinTrajet = 0
    nextVoisin = -1
    for i in listeClient:
        if matrix_local[cur][i] > 0 and (poidMinTrajet == 0 or matrix_local[cur][i] < poidMinTrajet):
            nextVoisin = i
            poidMinTrajet = matrix_local[cur][i]
    return nextVoisin, poidMinTrajet

def poidCycle():
    return sum(truckCycles[0])

# ================== Fonction demandée : recherche_tabou_cycle (avec matrices horaires) ==================

def recherche_tabou_cycle(matrix, start):
    tabou = deque(maxlen=len(matrix))
    tabou.append(start)
    ancientCandidats = list(range(len(matrix)))
    stop = False
    
    for i in range(nbTrucks):
        tabou.append(truckCycles[1][i][-1])

    while len(tabou) < len(matrix):

        truckAtMove = truckCycles[0].index(min(truckCycles[0]))
        cur = truckCycles[1][truckAtMove][-1]

        if  truckCycles[0][truckAtMove] < SEUIL1:
            matrixAtUse = matrix8h
        elif truckCycles[0][truckAtMove] < SEUIL2:
            matrixAtUse = matrix12h
        elif truckCycles[0][truckAtMove] >= MAX_CYCLE_TIME:
            print(f"Camion {truckAtMove} n'a plus de temps pour terminer sa tourné. Essayez avec plus de camions.")
            stop = True
            break
        else:
            matrixAtUse = matrix16h
        
        
        candidats = [i for i in ancientCandidats if i not in tabou]
        ancientCandidats = candidats


        if not candidats:
            break

        voisin, temps = voisinMinPoid(matrixAtUse, candidats, cur)

        truckCycles[1][truckAtMove].append(voisin)
        truckCycles[0][truckAtMove] += temps
        tabou.append(voisin)
        #print(f"Camion {truckAtMove+1} a utilisé la matrice {matrixAtUse} (temps ajouté : {temps}, temps total : {truckCycles[0][truckAtMove]})")

    # Retour au dépôt
    if stop == False:
        for i in range(nbTrucks):
            last_visited = truckCycles[1][i][-1]
            if truckCycles[0][i] + matrix[last_visited][depot] > MAX_CYCLE_TIME:
                print(f"Camion {i} ne peut pas retourner au dépôt sans dépasser le temps maximum.")
                stop = True
                break
            truckCycles[1][i].append(depot)
            truckCycles[0][i] += matrix[last_visited][depot]
    return stop


# ================== Recherche tabou multi-start (interface conservée) ==================
def tabou_multi_start(matrix_local, nb_lancements=20):
    tempsMeilleurCycle = float('inf')
    goodI = -1
    bestTime = None

    for i in range(nb_lancements):
        global truckCycles
        truckCycles = [
            [0] * nbTrucks,
            [[] for _ in range(nbTrucks)]
        ]

        for j in range(nbTrucks):
            truckCycles[1][j] = [depot]
            attempts = 0
            while True:
                attempts += 1
                if attempts > 1000:
                    raise RuntimeError("Impossible d'initialiser firstNeighbor (trop d'essais).")
                firstNeighbor = random.randint(1, len(matrix_local)-1)
                if not any(firstNeighbor in cycle for cycle in truckCycles[1]):
                    truckCycles[1][j].append(firstNeighbor)
                    truckCycles[0][j] = matrix_local[depot][firstNeighbor]
                    break

        stop = recherche_tabou_cycle(matrix_local, depot)

        if not stop:
            total = poidCycle()
            print(f"Lancement {i+1} terminé : Temps du cycle = {total}")

            print()
            for k in range(nbTrucks):
                print(f"Temps total du camion {k+1} : {truckCycles[0][k]}")
                
            print()
            if total < tempsMeilleurCycle:
                tempsMeilleurCycle = total
                goodI = i
                bestTime = [
                    truckCycles[0].copy(),
                    [cycle.copy() for cycle in truckCycles[1]]
                ]
                print(f"→ Nouveau meilleur cycle sauvegardé ! Lancement {i+1}.\n")       
        else:
            print(f"Lancement {i+1} interrompu prématurément en raison d'une contrainte de temps.\n")

    return tempsMeilleurCycle, goodI, bestTime

# ================== Partie bouchons (création des 3 matrices horaires) ==================
def generer_facteur_bouchon(heure):
    seed_value = hash(f"bouchon_{heure}") % (2**32)
    random.seed(seed_value)
    intensite = 0.5 + 0.5 * math.sin((heure - 8) / 24 * 2 * math.pi)
    facteur = 2.0 * intensite
    if facteur <= 0:
        facteur = 1
    return facteur

def facteurs_variation(matrice, pourcentage):
    n = len(matrice)
    toutes_les_routes = [(i, j) for i in range(n) for j in range(i + 1, n) if matrice[i][j] != 0]
    nb_a_modifier = int(len(toutes_les_routes) * pourcentage)
    if nb_a_modifier <= 0:
        return []
    routes_selectionnees = random.sample(toutes_les_routes, nb_a_modifier)
    for i, j in routes_selectionnees:
        p = random.uniform(-0.3, 0.3)
        nouvelle_valeur = matrice[i][j] * (1 + p)
        matrice[i][j] = matrice[j][i] = max(1, int(round(nouvelle_valeur)))
    return routes_selectionnees

def creer_fichiers_avec_bouchons():

    heures = [8, 12, 16]
    matrixCreated = []
    matrice_copie = copy.deepcopy(matrix)

 
    chemin_original = csv_path  
    try:
        matrice_base = lire_matrice_csv(chemin_original)
    except FileNotFoundError:
        print(f"Fichier source introuvable : {chemin_original}")
    

    n = len(matrice_base)
    base_name = os.path.basename(csv_path).replace('.csv','')

    for heure in heures:
        nom_sortie = f"matrice/{base_name}_{heure}h.csv"
        facteur_global = generer_facteur_bouchon(heure)

        proportion_routes_affectees = 0.3
        routes_affectees = set()
        for i in range(n):
            for j in range(i + 1, n):
                if random.random() < proportion_routes_affectees:
                    routes_affectees.add((i, j))

        for i in range(n):
            for j in range(i + 1, n):
                if (i, j) in routes_affectees:
                    variation_locale = random.uniform(0.8, 1.4)
                    facteur_total = facteur_global * variation_locale
                    nouvelle_valeur = int(round(matrice_base[i][j] * facteur_total))
                    matrice_copie[i][j] = matrice_copie[j][i] = nouvelle_valeur
                else:
                    matrice_copie[i][j] = matrice_copie[j][i] = int(matrice_base[i][j])

        # sauvegarde (écrase si existant)
        with open(nom_sortie, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerows(matrice_copie)

        print(f"✓ Fichier créé : {nom_sortie}")
        matrixCreated.append((nom_sortie))
    
    matrix8h = lire_matrice_csv(matrixCreated[0])
    matrix12h = lire_matrice_csv(matrixCreated[1])
    matrix16h = lire_matrice_csv(matrixCreated[2])


    return matrix8h, matrix12h, matrix16h
  
# ================== Fonctions de simulation / affichage (inchangées) ==================
def cout_effectif(matrice_local, i, j, heure):
    base = matrice_local[i][j]
    if base == 0:
        return 0
    facteur_bouchon = generer_facteur_bouchon(heure)
    cout = base * facteur_bouchon
    return max(1, int(round(cout, 0)))

def simulation_journee(matrice_local, nom_fichier):
    heures = list(range(0, 25, 4))
    for h in heures:
        facteur = generer_facteur_bouchon(h)
        cout_05 = cout_effectif(matrice_local, 0, 5, h)


# ================== Vérifications et tests ==================
'''
def verifier_modifications():
    print("VÉRIFICATION DES MODIFICATIONS")
    print("=" * 50)
    random.seed(42)

    try:
        matrice_test = lire_matrice_csv(csv_path)
    except FileNotFoundError:
        print(f"Fichier introuvable : {csv_path}")
        return

    n = len(matrice_test)
    routes_non_nulles_original = sum(1 for i in range(n) for j in range(i+1,n) if matrice_test[i][j] != 0)
    print(f"Routes non-nulles originales: {routes_non_nulles_original}")

    for heure in [8, 12, 16]:
        print(f"\n--- Heure {heure}h ---")
        matrice_copie = copy.deepcopy(matrice_test)
        random.seed(hash(f"test_{heure}") % (2**32))
        modifications = facteurs_variation(matrice_copie, 0.3)
        routes_modifiees = sum(1 for i in range(n) for j in range(i+1,n) if matrice_copie[i][j] != matrice_test[i][j])
        print(f"Routes modifiées comptées: {routes_modifiees}")
        print(f"Modifications annoncées: {len(modifications)}")
        print(f"COHÉRENT: {routes_modifiees == len(modifications)}")
'''
# ================== MAIN : exécution ==================
if __name__ == "__main__":
    matrix8h, matrix12h, matrix16h = creer_fichiers_avec_bouchons()

    #verifier_modifications()

    start_time = time.time()
    print("\n=== Démarrage de la recherche tabou multi-start ===")
    print()
    tempsMeilleurCycle, goodI, bestTime = tabou_multi_start(matrix)
    execution_time = (time.time() - start_time) * 1000

    print("\n=== Meilleur cycle trouvé ===")
    if goodI != -1:
        print("Lancement n°", goodI+1, "  Temps du cycle :", tempsMeilleurCycle)
        for i in range(nbTrucks):
            print(f"Cycle du camion {i+1} : ", " -> ".join(str(x+1) for x in bestTime[1][i]))
            print(f"Temps total du camion {i+1} : {bestTime[0][i]}\n")
    else:
        print("Aucun cycle valide n'a été trouvé avec les contraintes données.")
        

    
    if execution_time < 1000:
        print("Temps d'exécution :", round(execution_time, 2), "ms")
    elif execution_time < 60000:
        print("Temps d'exécution :", round(execution_time / 1000, 2), "s")
    else:
        print("Temps d'exécution :", round(execution_time / 60000, 2), "min")
# Out:
# === Sélection de l'instance ===
# 1 - 6X6.csv
# 2 - 11X11.csv
# 3 - 51X51.csv
# 4 - 101X101.csv
# 5 - 201X201.csv
# 6 - 501X501.csv
# 7 - 1001X1001.csv
# 8 - 1501X1501.csv
# 9 - 2001X2001.csv
# ✓ Fichier créé : matrice/201X201_8h.csv
# ✓ Fichier créé : matrice/201X201_12h.csv
# ✓ Fichier créé : matrice/201X201_16h.csv
#
# === Démarrage de la recherche tabou multi-start ===
#
# Lancement 1 terminé : Temps du cycle = 2251
#
# Temps total du camion 1 : 87
# Temps total du camion 2 : 78
# Temps total du camion 3 : 114
# Temps total du camion 4 : 94
# Temps total du camion 5 : 95
# Temps total du camion 6 : 75
# Temps total du camion 7 : 102
# Temps total du camion 8 : 91
# Temps total du camion 9 : 88
# Temps total du camion 10 : 109
# Temps total du camion 11 : 94
# Temps total du camion 12 : 107
# Temps total du camion 13 : 73
# Temps total du camion 14 : 97
# Temps total du camion 15 : 85
# Temps total du camion 16 : 90
# Temps total du camion 17 : 96
# Temps total du camion 18 : 84
# Temps total du camion 19 : 80
# Temps total du camion 20 : 88
# Temps total du camion 21 : 94
# Temps total du camion 22 : 78
# Temps total du camion 23 : 92
# Temps total du camion 24 : 81
# Temps total du camion 25 : 79
#
# → Nouveau meilleur cycle sauvegardé ! Lancement 1.
#
# Lancement 2 terminé : Temps du cycle = 2344
#
# Temps total du camion 1 : 96
# Temps total du camion 2 : 91
# Temps total du camion 3 : 92
# Temps total du camion 4 : 95
# Temps total du camion 5 : 75
# Temps total du camion 6 : 91
# Temps total du camion 7 : 103
# Temps total du camion 8 : 96
# Temps total du camion 9 : 93
# Temps total du camion 10 : 112
# Temps total du camion 11 : 96
# Temps total du camion 12 : 105
# Temps total du camion 13 : 75
# Temps total du camion 14 : 111
# Temps total du camion 15 : 88
# Temps total du camion 16 : 85
# Temps total du camion 17 : 104
# Temps total du camion 18 : 77
# Temps total du camion 19 : 105
# Temps total du camion 20 : 90
# Temps total du camion 21 : 95
# Temps total du camion 22 : 86
# Temps total du camion 23 : 93
# Temps total du camion 24 : 86
# Temps total du camion 25 : 104
#
# Lancement 3 terminé : Temps du cycle = 2432
#
# Temps total du camion 1 : 73
# Temps total du camion 2 : 114
# Temps total du camion 3 : 92
# Temps total du camion 4 : 91
# Temps total du camion 5 : 92
# Temps total du camion 6 : 104
# Temps total du camion 7 : 96
# Temps total du camion 8 : 103
# Temps total du camion 9 : 96
# Temps total du camion 10 : 100
# Temps total du camion 11 : 71
# Temps total du camion 12 : 92
# Temps total du camion 13 : 72
# Temps total du camion 14 : 132
# Temps total du camion 15 : 91
# Temps total du camion 16 : 81
# Temps total du camion 17 : 98
# Temps total du camion 18 : 104
# Temps total du camion 19 : 88
# Temps total du camion 20 : 112
# Temps total du camion 21 : 75
# Temps total du camion 22 : 124
# Temps total du camion 23 : 110
# Temps total du camion 24 : 121
# Temps total du camion 25 : 100
#
# Lancement 4 terminé : Temps du cycle = 2548
#
# Temps total du camion 1 : 97
# Temps total du camion 2 : 122
# Temps total du camion 3 : 126
# Temps total du camion 4 : 114
# Temps total du camion 5 : 99
# Temps total du camion 6 : 93
# Temps total du camion 7 : 98
# Temps total du camion 8 : 95
# Temps total du camion 9 : 102
# Temps total du camion 10 : 80
# Temps total du camion 11 : 85
# Temps total du camion 12 : 102
# Temps total du camion 13 : 118
# Temps total du camion 14 : 102
# Temps total du camion 15 : 112
# Temps total du camion 16 : 93
# Temps total du camion 17 : 97
# Temps total du camion 18 : 117
# Temps total du camion 19 : 92
# Temps total du camion 20 : 117
# Temps total du camion 21 : 94
# Temps total du camion 22 : 100
# Temps total du camion 23 : 104
# Temps total du camion 24 : 72
# Temps total du camion 25 : 117
#
# Lancement 5 terminé : Temps du cycle = 2443
#
# Temps total du camion 1 : 132
# Temps total du camion 2 : 96
# Temps total du camion 3 : 89
# Temps total du camion 4 : 93
# Temps total du camion 5 : 86
# Temps total du camion 6 : 90
# Temps total du camion 7 : 102
# Temps total du camion 8 : 93
# Temps total du camion 9 : 88
# Temps total du camion 10 : 81
# Temps total du camion 11 : 95
# Temps total du camion 12 : 99
# Temps total du camion 13 : 94
# Temps total du camion 14 : 99
# Temps total du camion 15 : 120
# Temps total du camion 16 : 126
# Temps total du camion 17 : 82
# Temps total du camion 18 : 98
# Temps total du camion 19 : 95
# Temps total du camion 20 : 109
# Temps total du camion 21 : 94
# Temps total du camion 22 : 63
# Temps total du camion 23 : 93
# Temps total du camion 24 : 114
# Temps total du camion 25 : 112
#
# Lancement 6 terminé : Temps du cycle = 2446
#
# Temps total du camion 1 : 104
# Temps total du camion 2 : 93
# Temps total du camion 3 : 91
# Temps total du camion 4 : 103
# Temps total du camion 5 : 88
# Temps total du camion 6 : 100
# Temps total du camion 7 : 119
# Temps total du camion 8 : 98
# Temps total du camion 9 : 88
# Temps total du camion 10 : 106
# Temps total du camion 11 : 95
# Temps total du camion 12 : 91
# Temps total du camion 13 : 95
# Temps total du camion 14 : 78
# Temps total du camion 15 : 108
# Temps total du camion 16 : 98
# Temps total du camion 17 : 90
# Temps total du camion 18 : 105
# Temps total du camion 19 : 124
# Temps total du camion 20 : 99
# Temps total du camion 21 : 97
# Temps total du camion 22 : 89
# Temps total du camion 23 : 90
# Temps total du camion 24 : 120
# Temps total du camion 25 : 77
#
# Lancement 7 terminé : Temps du cycle = 2464
#
# Temps total du camion 1 : 93
# Temps total du camion 2 : 109
# Temps total du camion 3 : 98
# Temps total du camion 4 : 98
# Temps total du camion 5 : 103
# Temps total du camion 6 : 125
# Temps total du camion 7 : 97
# Temps total du camion 8 : 116
# Temps total du camion 9 : 86
# Temps total du camion 10 : 77
# Temps total du camion 11 : 86
# Temps total du camion 12 : 105
# Temps total du camion 13 : 125
# Temps total du camion 14 : 131
# Temps total du camion 15 : 100
# Temps total du camion 16 : 78
# Temps total du camion 17 : 87
# Temps total du camion 18 : 81
# Temps total du camion 19 : 91
# Temps total du camion 20 : 104
# Temps total du camion 21 : 91
# Temps total du camion 22 : 97
# Temps total du camion 23 : 103
# Temps total du camion 24 : 98
# Temps total du camion 25 : 85
#
# Lancement 8 terminé : Temps du cycle = 2410
#
# Temps total du camion 1 : 122
# Temps total du camion 2 : 110
# Temps total du camion 3 : 93
# Temps total du camion 4 : 98
# Temps total du camion 5 : 91
# Temps total du camion 6 : 88
# Temps total du camion 7 : 76
# Temps total du camion 8 : 78
# Temps total du camion 9 : 132
# Temps total du camion 10 : 104
# Temps total du camion 11 : 98
# Temps total du camion 12 : 83
# Temps total du camion 13 : 97
# Temps total du camion 14 : 100
# Temps total du camion 15 : 75
# Temps total du camion 16 : 97
# Temps total du camion 17 : 87
# Temps total du camion 18 : 99
# Temps total du camion 19 : 81
# Temps total du camion 20 : 92
# Temps total du camion 21 : 92
# Temps total du camion 22 : 101
# Temps total du camion 23 : 105
# Temps total du camion 24 : 113
# Temps total du camion 25 : 98
#
# Lancement 9 terminé : Temps du cycle = 2458
#
# Temps total du camion 1 : 131
# Temps total du camion 2 : 71
# Temps total du camion 3 : 119
# Temps total du camion 4 : 109
# Temps total du camion 5 : 96
# Temps total du camion 6 : 107
# Temps total du camion 7 : 137
# Temps total du camion 8 : 67
# Temps total du camion 9 : 84
# Temps total du camion 10 : 103
# Temps total du camion 11 : 98
# Temps total du camion 12 : 96
# Temps total du camion 13 : 93
# Temps total du camion 14 : 126
# Temps total du camion 15 : 89
# Temps total du camion 16 : 121
# Temps total du camion 17 : 72
# Temps total du camion 18 : 128
# Temps total du camion 19 : 96
# Temps total du camion 20 : 84
# Temps total du camion 21 : 73
# Temps total du camion 22 : 101
# Temps total du camion 23 : 70
# Temps total du camion 24 : 111
# Temps total du camion 25 : 76
#
# Lancement 10 terminé : Temps du cycle = 2623
#
# Temps total du camion 1 : 86
# Temps total du camion 2 : 83
# Temps total du camion 3 : 116
# Temps total du camion 4 : 100
# Temps total du camion 5 : 91
# Temps total du camion 6 : 116
# Temps total du camion 7 : 105
# Temps total du camion 8 : 97
# Temps total du camion 9 : 121
# Temps total du camion 10 : 97
# Temps total du camion 11 : 117
# Temps total du camion 12 : 122
# Temps total du camion 13 : 97
# Temps total du camion 14 : 119
# Temps total du camion 15 : 96
# Temps total du camion 16 : 78
# Temps total du camion 17 : 107
# Temps total du camion 18 : 105
# Temps total du camion 19 : 95
# Temps total du camion 20 : 125
# Temps total du camion 21 : 138
# Temps total du camion 22 : 95
# Temps total du camion 23 : 114
# Temps total du camion 24 : 101
# Temps total du camion 25 : 102
#
# Lancement 11 terminé : Temps du cycle = 2257
#
# Temps total du camion 1 : 94
# Temps total du camion 2 : 96
# Temps total du camion 3 : 71
# Temps total du camion 4 : 84
# Temps total du camion 5 : 90
# Temps total du camion 6 : 95
# Temps total du camion 7 : 91
# Temps total du camion 8 : 84
# Temps total du camion 9 : 119
# Temps total du camion 10 : 99
# Temps total du camion 11 : 94
# Temps total du camion 12 : 67
# Temps total du camion 13 : 77
# Temps total du camion 14 : 84
# Temps total du camion 15 : 99
# Temps total du camion 16 : 89
# Temps total du camion 17 : 88
# Temps total du camion 18 : 91
# Temps total du camion 19 : 89
# Temps total du camion 20 : 91
# Temps total du camion 21 : 84
# Temps total du camion 22 : 90
# Temps total du camion 23 : 85
# Temps total du camion 24 : 104
# Temps total du camion 25 : 102
#
# Lancement 12 terminé : Temps du cycle = 2533
#
# Temps total du camion 1 : 100
# Temps total du camion 2 : 73
# Temps total du camion 3 : 99
# Temps total du camion 4 : 90
# Temps total du camion 5 : 100
# Temps total du camion 6 : 116
# Temps total du camion 7 : 96
# Temps total du camion 8 : 99
# Temps total du camion 9 : 83
# Temps total du camion 10 : 120
# Temps total du camion 11 : 78
# Temps total du camion 12 : 134
# Temps total du camion 13 : 100
# Temps total du camion 14 : 89
# Temps total du camion 15 : 112
# Temps total du camion 16 : 87
# Temps total du camion 17 : 99
# Temps total du camion 18 : 87
# Temps total du camion 19 : 117
# Temps total du camion 20 : 103
# Temps total du camion 21 : 142
# Temps total du camion 22 : 99
# Temps total du camion 23 : 104
# Temps total du camion 24 : 107
# Temps total du camion 25 : 99
#
# Lancement 13 terminé : Temps du cycle = 2333
#
# Temps total du camion 1 : 96
# Temps total du camion 2 : 69
# Temps total du camion 3 : 68
# Temps total du camion 4 : 118
# Temps total du camion 5 : 86
# Temps total du camion 6 : 92
# Temps total du camion 7 : 94
# Temps total du camion 8 : 86
# Temps total du camion 9 : 87
# Temps total du camion 10 : 90
# Temps total du camion 11 : 80
# Temps total du camion 12 : 94
# Temps total du camion 13 : 97
# Temps total du camion 14 : 96
# Temps total du camion 15 : 133
# Temps total du camion 16 : 99
# Temps total du camion 17 : 76
# Temps total du camion 18 : 80
# Temps total du camion 19 : 95
# Temps total du camion 20 : 86
# Temps total du camion 21 : 78
# Temps total du camion 22 : 116
# Temps total du camion 23 : 127
# Temps total du camion 24 : 98
# Temps total du camion 25 : 92
#
# Lancement 14 terminé : Temps du cycle = 2447
#
# Temps total du camion 1 : 111
# Temps total du camion 2 : 113
# Temps total du camion 3 : 103
# Temps total du camion 4 : 100
# Temps total du camion 5 : 82
# Temps total du camion 6 : 96
# Temps total du camion 7 : 93
# Temps total du camion 8 : 113
# Temps total du camion 9 : 102
# Temps total du camion 10 : 106
# Temps total du camion 11 : 79
# Temps total du camion 12 : 82
# Temps total du camion 13 : 89
# Temps total du camion 14 : 98
# Temps total du camion 15 : 89
# Temps total du camion 16 : 122
# Temps total du camion 17 : 110
# Temps total du camion 18 : 84
# Temps total du camion 19 : 91
# Temps total du camion 20 : 110
# Temps total du camion 21 : 80
# Temps total du camion 22 : 101
# Temps total du camion 23 : 102
# Temps total du camion 24 : 96
# Temps total du camion 25 : 95
#
# Lancement 15 terminé : Temps du cycle = 2527
#
# Temps total du camion 1 : 90
# Temps total du camion 2 : 87
# Temps total du camion 3 : 98
# Temps total du camion 4 : 105
# Temps total du camion 5 : 95
# Temps total du camion 6 : 81
# Temps total du camion 7 : 91
# Temps total du camion 8 : 91
# Temps total du camion 9 : 85
# Temps total du camion 10 : 81
# Temps total du camion 11 : 107
# Temps total du camion 12 : 115
# Temps total du camion 13 : 127
# Temps total du camion 14 : 122
# Temps total du camion 15 : 87
# Temps total du camion 16 : 92
# Temps total du camion 17 : 103
# Temps total du camion 18 : 93
# Temps total du camion 19 : 129
# Temps total du camion 20 : 137
# Temps total du camion 21 : 120
# Temps total du camion 22 : 87
# Temps total du camion 23 : 125
# Temps total du camion 24 : 98
# Temps total du camion 25 : 81
#
# Lancement 16 terminé : Temps du cycle = 2409
#
# Temps total du camion 1 : 83
# Temps total du camion 2 : 100
# Temps total du camion 3 : 107
# Temps total du camion 4 : 88
# Temps total du camion 5 : 83
# Temps total du camion 6 : 99
# Temps total du camion 7 : 91
# Temps total du camion 8 : 74
# Temps total du camion 9 : 109
# Temps total du camion 10 : 100
# Temps total du camion 11 : 102
# Temps total du camion 12 : 68
# Temps total du camion 13 : 115
# Temps total du camion 14 : 85
# Temps total du camion 15 : 99
# Temps total du camion 16 : 102
# Temps total du camion 17 : 97
# Temps total du camion 18 : 86
# Temps total du camion 19 : 123
# Temps total du camion 20 : 122
# Temps total du camion 21 : 113
# Temps total du camion 22 : 74
# Temps total du camion 23 : 99
# Temps total du camion 24 : 95
# Temps total du camion 25 : 95
#
# Lancement 17 terminé : Temps du cycle = 2538
#
# Temps total du camion 1 : 99
# Temps total du camion 2 : 98
# Temps total du camion 3 : 111
# Temps total du camion 4 : 85
# Temps total du camion 5 : 83
# Temps total du camion 6 : 109
# Temps total du camion 7 : 98
# Temps total du camion 8 : 86
# Temps total du camion 9 : 95
# Temps total du camion 10 : 117
# Temps total du camion 11 : 81
# Temps total du camion 12 : 96
# Temps total du camion 13 : 102
# Temps total du camion 14 : 135
# Temps total du camion 15 : 101
# Temps total du camion 16 : 142
# Temps total du camion 17 : 107
# Temps total du camion 18 : 95
# Temps total du camion 19 : 107
# Temps total du camion 20 : 99
# Temps total du camion 21 : 93
# Temps total du camion 22 : 97
# Temps total du camion 23 : 99
# Temps total du camion 24 : 105
# Temps total du camion 25 : 98
#
# Lancement 18 terminé : Temps du cycle = 2224
#
# Temps total du camion 1 : 107
# Temps total du camion 2 : 81
# Temps total du camion 3 : 92
# Temps total du camion 4 : 85
# Temps total du camion 5 : 92
# Temps total du camion 6 : 89
# Temps total du camion 7 : 89
# Temps total du camion 8 : 93
# Temps total du camion 9 : 97
# Temps total du camion 10 : 81
# Temps total du camion 11 : 69
# Temps total du camion 12 : 111
# Temps total du camion 13 : 72
# Temps total du camion 14 : 79
# Temps total du camion 15 : 86
# Temps total du camion 16 : 98
# Temps total du camion 17 : 87
# Temps total du camion 18 : 105
# Temps total du camion 19 : 82
# Temps total du camion 20 : 98
# Temps total du camion 21 : 86
# Temps total du camion 22 : 91
# Temps total du camion 23 : 91
# Temps total du camion 24 : 79
# Temps total du camion 25 : 84
#
# → Nouveau meilleur cycle sauvegardé ! Lancement 18.
#
# Lancement 19 terminé : Temps du cycle = 2326
#
# Temps total du camion 1 : 71
# Temps total du camion 2 : 94
# Temps total du camion 3 : 103
# Temps total du camion 4 : 102
# Temps total du camion 5 : 94
# Temps total du camion 6 : 97
# Temps total du camion 7 : 91
# Temps total du camion 8 : 71
# Temps total du camion 9 : 74
# Temps total du camion 10 : 98
# Temps total du camion 11 : 113
# Temps total du camion 12 : 72
# Temps total du camion 13 : 91
# Temps total du camion 14 : 94
# Temps total du camion 15 : 115
# Temps total du camion 16 : 85
# Temps total du camion 17 : 116
# Temps total du camion 18 : 89
# Temps total du camion 19 : 102
# Temps total du camion 20 : 83
# Temps total du camion 21 : 81
# Temps total du camion 22 : 92
# Temps total du camion 23 : 102
# Temps total du camion 24 : 98
# Temps total du camion 25 : 98
#
# Lancement 20 terminé : Temps du cycle = 2529
#
# Temps total du camion 1 : 85
# Temps total du camion 2 : 105
# Temps total du camion 3 : 87
# Temps total du camion 4 : 87
# Temps total du camion 5 : 93
# Temps total du camion 6 : 104
# Temps total du camion 7 : 95
# Temps total du camion 8 : 107
# Temps total du camion 9 : 131
# Temps total du camion 10 : 85
# Temps total du camion 11 : 97
# Temps total du camion 12 : 115
# Temps total du camion 13 : 101
# Temps total du camion 14 : 134
# Temps total du camion 15 : 100
# Temps total du camion 16 : 80
# Temps total du camion 17 : 71
# Temps total du camion 18 : 120
# Temps total du camion 19 : 117
# Temps total du camion 20 : 107
# Temps total du camion 21 : 88
# Temps total du camion 22 : 101
# Temps total du camion 23 : 105
# Temps total du camion 24 : 105
# Temps total du camion 25 : 109
#
#
# === Meilleur cycle trouvé ===
# Lancement n° 18   Temps du cycle : 2224
# Cycle du camion 1 :  1 -> 87 -> 52 -> 22 -> 186 -> 136 -> 67 -> 1
# Temps total du camion 1 : 107
#
# Cycle du camion 2 :  1 -> 162 -> 129 -> 76 -> 127 -> 158 -> 111 -> 49 -> 85 -> 18 -> 82 -> 167 -> 92 -> 4 -> 1
# Temps total du camion 2 : 81
#
# Cycle du camion 3 :  1 -> 50 -> 86 -> 135 -> 77 -> 184 -> 1
# Temps total du camion 3 : 92
#
# Cycle du camion 4 :  1 -> 110 -> 57 -> 177 -> 172 -> 60 -> 96 -> 1
# Temps total du camion 4 : 85
#
# Cycle du camion 5 :  1 -> 39 -> 11 -> 73 -> 51 -> 32 -> 75 -> 84 -> 1
# Temps total du camion 5 : 92
#
# Cycle du camion 6 :  1 -> 13 -> 102 -> 46 -> 28 -> 163 -> 1
# Temps total du camion 6 : 89
#
# Cycle du camion 7 :  1 -> 151 -> 105 -> 42 -> 1
# Temps total du camion 7 : 89
#
# Cycle du camion 8 :  1 -> 147 -> 109 -> 200 -> 63 -> 83 -> 1
# Temps total du camion 8 : 93
#
# Cycle du camion 9 :  1 -> 165 -> 180 -> 139 -> 88 -> 183 -> 89 -> 100 -> 123 -> 1
# Temps total du camion 9 : 97
#
# Cycle du camion 10 :  1 -> 157 -> 99 -> 2 -> 145 -> 116 -> 196 -> 19 -> 160 -> 175 -> 44 -> 106 -> 1
# Temps total du camion 10 : 81
#
# Cycle du camion 11 :  1 -> 8 -> 55 -> 91 -> 10 -> 138 -> 185 -> 188 -> 62 -> 132 -> 1
# Temps total du camion 11 : 69
#
# Cycle du camion 12 :  1 -> 14 -> 21 -> 27 -> 103 -> 37 -> 34 -> 104 -> 169 -> 152 -> 171 -> 1
# Temps total du camion 12 : 111
#
# Cycle du camion 13 :  1 -> 155 -> 35 -> 5 -> 70 -> 7 -> 20 -> 64 -> 43 -> 108 -> 120 -> 166 -> 41 -> 81 -> 98 -> 124 -> 1
# Temps total du camion 13 : 72
#
# Cycle du camion 14 :  1 -> 90 -> 159 -> 146 -> 36 -> 47 -> 191 -> 1
# Temps total du camion 14 : 79
#
# Cycle du camion 15 :  1 -> 190 -> 25 -> 61 -> 125 -> 33 -> 58 -> 148 -> 1
# Temps total du camion 15 : 86
#
# Cycle du camion 16 :  1 -> 178 -> 153 -> 16 -> 168 -> 117 -> 119 -> 187 -> 30 -> 24 -> 31 -> 3 -> 1
# Temps total du camion 16 : 98
#
# Cycle du camion 17 :  1 -> 59 -> 93 -> 38 -> 107 -> 48 -> 1
# Temps total du camion 17 : 87
#
# Cycle du camion 18 :  1 -> 23 -> 40 -> 72 -> 114 -> 199 -> 137 -> 197 -> 192 -> 144 -> 71 -> 1
# Temps total du camion 18 : 105
#
# Cycle du camion 19 :  1 -> 101 -> 54 -> 149 -> 161 -> 130 -> 193 -> 141 -> 6 -> 126 -> 201 -> 112 -> 118 -> 121 -> 122 -> 53 -> 79 -> 174 -> 143 -> 95 -> 1
# Temps total du camion 19 : 82
#
# Cycle du camion 20 :  1 -> 29 -> 113 -> 1
# Temps total du camion 20 : 98
#
# Cycle du camion 21 :  1 -> 26 -> 115 -> 140 -> 154 -> 182 -> 195 -> 181 -> 198 -> 56 -> 1
# Temps total du camion 21 : 86
#
# Cycle du camion 22 :  1 -> 68 -> 12 -> 134 -> 131 -> 156 -> 1
# Temps total du camion 22 : 91
#
# Cycle du camion 23 :  1 -> 80 -> 97 -> 94 -> 133 -> 189 -> 179 -> 142 -> 1
# Temps total du camion 23 : 91
#
# Cycle du camion 24 :  1 -> 150 -> 128 -> 170 -> 176 -> 78 -> 17 -> 173 -> 15 -> 164 -> 65 -> 9 -> 1
# Temps total du camion 24 : 79
#
# Cycle du camion 25 :  1 -> 45 -> 74 -> 194 -> 66 -> 69 -> 1
# Temps total du camion 25 : 84
#
# Temps d'exécution : 339.52 ms
